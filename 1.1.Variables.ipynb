# %% [markdown]
# ### Hoy vamos a ver:
# #### - Visual Studio Code: crear un Jupyter, guardar, code & markdown, activar código
# #### - Comentar dentro del código
# #### - Variables
# #### - Variables numéricas
# #### - Variables de texto
# #### - Variables booleanas
# #### - print() y f-string
# #### - input()
# #### - Operadores de comparación

# %% [markdown]
# Jupyter --> File, New File, Jupyter Notebook
# Guardar -> Save

# %% [markdown]
# Activar celda: Control + enter o play

# %% [markdown]
# Markdown

# %% [markdown]
# # Hola
# ## Subtítulo
# ### Subtítulo 2
# #### Subtítulo #3
# _tema_
#
# **texto**
# - uno
# - dos
# - tres

# %% [markdown]
# Comentar dentro del código: el uso de # y """ """

# %%
#esta variable es mi edad
a = 30 #esto es un comentario
#esta segunda variable es el dinero que tengo
b = 150

# %%
'''Estas van a ser mis variables.
Se llamarán a y b'''

a = 30
b = 150

"""Estas comillas también pueden usarse para comentar código.
Y son multilínea."""

# %%
#Variables

# %%
libros = 30
edad = 50
kilos = 2.5

# %%
edad * 50

# %%
print(edad * 50)

# %%
print(libros * kilos)

# %%
nombre_cliente = "María Martínez"
sueldo = 1500
sueldo_anual = 50000

# %%
sueldo_anual

# %%
nombre_cliente

# %% [markdown]
# ¿Qué es una variable? ¿Cómo nombrarla?
#
# Tipos de variables:
#
# - Numéricas
#     - Para pasar a entero int()
#     - Para pasar a decimal float()
# - Cadena de texto
#     - Para pasar una variable a string usamos str()
# - Booleanas
#     - Para pasar una variable a booleano usamos bool()

# %%
mi_variable = 6.0 #¿De qué tipo es?

# %%
type(mi_variable)

# %%
num = int(mi_variable)

# %%
print(num)

# %%
texto = str(54)

# %%
print(texto)

# %%
print(texto * 20)

# %%
variable_num = 1
variable_decimal = 1.5

# %%
variable_num = variable_num * 10 #guardar cambios en la misma variable

# %%
variable_num

# %% [markdown]
# ## NUMÉRICAS
# Operaciones algebraicas: +, -, *, /
# - //
# - %
# - **
# - pow()
# - divmod()
# - round()
# - abs()
# - max()
# - min()
# - sorted(())
# - sum(())

# %%
4 + 5

# %%
patatas = 10
tomates = 44

print(patatas + tomates)

# %%
patatas - tomates

# %%
patatas * tomates

# %%
255/3

# %%
255//3 #Nos da el resto, sin decimales

# %%
10%2 #Nos da el resto

# %%
2**2 #Nos da un número elevado al otro

# %%
pow(2,2) #Lo mismo

# %%
divmod(6,3) #divide el primero por el segundo y nos da el cociente y el resto

# %%
round(456/239,2) #Para redondear un número

# %%
round(3.4995949494,5)

# %%
abs(-4)

# %%
max(2,4,7,1,2,7,6,4,2)

# %%
min(5,4,2,4,0,5.5)

# %%
saldo = 2.58839394841

# %%
round(saldo,2)

# %%
sum((20, 30, 40))

# %%
sorted((40,4,14,34))

# %%
#Las variables se pueden comparar y nos devuelven booleanos (True o False)
# ==, !=, >=, <=, <, >, in, not in

# %%
20 >= 20

# %%
20 % 2 == 0

# %%
20 % 2 != 0

# %%
20 > 30

# %%
'Python' in 'Me encanta Python'

# %%
num1 = 50
num2 = 5

# %%
print(num1*num2)

# %%
print(num1/num2)

# %%
print(num1//num2)

# %%
naranja = 1
fresa = 4
platano = 20
fruta_menor = min(naranja, fresa, platano) #puedo guardar el resultado en una variable nueva

# %%
fruta_menor

# %%
#Strings

# %%
print('Hola, qué tal')

# %%
nombre = "Marta Martín"
edad = 40
altura = 1.70
clienta = False

# %%
print(f"Mi nombre es {nombre}.") #Esto es un f-string

# %%
print(f"Hola qué tal, {nombre}, sé que tienes {edad} años y que mides {altura}")

# %%
print(f"Hola, {nombre}, como tienes {edad} y mides {altura}, te ofrecemos esta oferta.")

# %% [markdown]
# CADENAS DE TEXTO O STRING
#
# - .upper()
# - .lower()
# - .title()
# - .capitalize()
# - .swapcase()
# - .strip()
# - .split()
# - .replace()
# - len()
# - .find()
# - .count()

# %%
mi_texto = "Hoy es nuestro primer día en Adalab"

# %%
mi_texto.upper()

# %%
#Pero si lo quiero guardar...
mi_texto = mi_texto.upper()

# %%
mi_texto.lower()

# %%
mi_texto2 = mi_texto.title()

# %%
mi_texto.capitalize()

# %%
mi_texto.swapcase()

# %%
frase = "  hola que tal  "

# %%
frase.strip()

# %%
frase2 = "hola, qué tal, yo bien, y tu"

# %%
frase2.split(",")

# %%
mi_texto

# %%
len(mi_texto)

# %%
mi_texto = mi_texto.replace("primer", "segundo")

# %%
mi_texto.find("Adalab")

# %%
variable_texto = "Me gusta mucho python, pero no me gusta tanto java"

# %%
variable_texto.count("gusta")

# %%
#INDEXING Y SLICING / CONCATENACIÓN
#start:stop:step

# %%
"Casa"[0:3]

# %%
"Python"[3:4]

# %%
"Me gusta el chocolate"[0:8:3]

# %%
#input

# %% [markdown]
# Introducir datos: input()
# - por defecto, lo que introducimos es string
# - si es numérico, hay que señalarlo

# %%
jugador1 = input("Dime tu nombre jugador1, por favor")

# %%
jugador2 = input("Dime tu nombre jugador2, por favor")

# %%
print(nombre)

# %%
print(f"Bienvenidas {jugador1} y {jugador2}")

# %%
jugar = input("¿Quiere seguir jugando? Escriba sí o no")

# %%
altura = float(input("Dime tu altura"))

# %%
edad = int(input("Dime tu edad, por favor"))

# %%
altura

# %%
edad

# %%
int()
str()
float()

# %%
print(f"Hola, {nombre}, sé que tienes {edad} años")

# %% [markdown]
# BOOLEANOS: TRUE O FALSE
# - in
# - not in
# - not, and, or
# - comparadores
# - si una variable está vacía, es cero o nulo: False

# %%
numero = 20

# %%
numero == 20

# %%
numero >= 20

# %%
cancion = "Qué bonito está el día"

# %%
"día" in cancion

# %% [markdown]
# Operadores de comparación
# **==**
# **!=**
# **<**
# **<=**
# **>=**
# **>=**

# %%
20 != 20

# %%
numero > 10 and numero > 20

# %%
texto_prueba = "Me encanta Harry Potter, de hecho soy de Ravenclaw"

# %%
casa = input("Dime tu casa, porfa:")

# %%
veces = int(input("¿Cuántas veces te has leído los libros de Harry Potter"))

# %%
print(f"Sé que eres de la casa {casa} y te has leído los libros {veces} veces.")

# %% [markdown]
# ### Convierte un texto en mayúsculas, luego a minúsculas, reemplaza una palabra por otra, luego separa las palabras por espacios en una variable nueva y luego comprueba si tiene una palabra en concreto

# %%
texto = "Me gusta el chachacha"

# %% [markdown]
# ### Pide al usuario dos números y realiza suma, resta, división entera y comparación con ellos.
